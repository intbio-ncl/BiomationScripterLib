# %%
####################################################
# Import BiomationScripter to help write protocols #
####################################################
import sys
sys.path.insert(0, "/var/lib/jupyter/notebooks/Packages/BiomationScripterLib")
import BiomationScripter as BMS
import BiomationScripter.OTProto.Templates as Templates

# %%
##################################
# Record the protocol's metadata #
##################################
metadata = {
    'protocolName': 'Transformation Example',
    'author': 'Bradley Brown',
    'author-email': 'b.bradley2@newcastle.ac.uk',
    'user': '',
    'user-email': '',
    'source': 'Generated using BiomationScripter',
    'apiLevel': '2.11',
    'robotName': 'RobOT2' # This is the name of the OT2 you plan to run the protocol on
}

# %%
##############################################################
# Use this cell to call the Transformation protocol template #
##############################################################

def run(protocol):
    
    #################################################
    # Add information needed for the protocol here: #
    #################################################
    
    Custom_Labware_Dir = "../../../../Resources/data/custom_labware"
    
    # DNA Plate Info #
    
    DNA_Plate_Wells = [
        "B2",
        "B3",
        "B4",
        "B5",
        "B6",
        "B7",
        "B8",
        "B9",
        "B10",
        "B11",
        "B12",
    ]
    
    DNA_Plate_Content = [
        "Assembly 1",
        "Assembly 2",
        "Assembly 3",
        "Assembly 4",
        "Assembly 5",
        "Assembly 6",
        "Assembly 7",
        "Assembly 8",
        "Assembly 9",
        "Assembly 10",
        "Assembly 11",
    ]
    
    DNA_Plate = BMS.Labware_Layout("DNA Plate", "appliedbiosystemsmicroampoptical_384_wellplate_20ul")
    
    DNA_Plate.bulk_add_content(
        Wells = DNA_Plate_Wells,
        Reagents = DNA_Plate_Content,
        Volumes = 20
    )
    
    # DNA Tubes Info #
    
    DNA_Tubes_Wells = [
        "A1",
        "A2"
    ]
    
    DNA_Tubes_Content = [
        "Positive",
        "Negative"
    ]
    
    DNA_Tubes = BMS.Labware_Layout("DNA Tubes", "3dprinted_24_tuberack_1500ul")
    
    DNA_Tubes.bulk_add_content(
        Wells = DNA_Tubes_Wells,
        Reagents = DNA_Tubes_Content,
        Volumes = 5
    )
    
    DNA_Source_Layouts = [DNA_Plate, DNA_Tubes]
    
    # Other labware and material info #
    
    Competent_Cells_Source_Type = "3dprinted_24_tuberack_1500ul"
    
    Comp_Cells_Modules = ["temperature module gen2"]
    
    Media_Source_Type = "3dprinted_15_tuberack_15000ul"
    Transformation_Destination_Type = "nunclondeltasurface163320_96_wellplate_250ul"
    
    Competent_Cells_Aliquot_Vol = 50 # uL
    Media_Aliquot_Vol = 5000 # uL
    
    # Protocol Parameters #
    
    DNA_Per_Transformation = 3 # uL
    Competent_Cells_Volume = 20 # uL
    Final_Volume = 100 # uL
    Heat_Shock_Time = 30 # Seconds
    Heat_Shock_Temp = 42 # celcius
    Wait_Before_Shock = 300 # seconds
    Reps = 1
    
    # Starting Tips #
    
    Starting_20uL_Tip = "A8"
    Starting_300uL_Tip = "A1"
    
    #################################################
    #################################################
    #################################################
    
    ##############################################################
    # The code below creates the protocol to be ran or simulated #
    ##############################################################
    
    Transformation = BMS.OTProto.Templates.Heat_Shock_Transformation(
        Protocol=protocol,
        Name=metadata["protocolName"],
        Metadata=metadata,
        DNA_Source_Layouts=DNA_Source_Layouts,
        Competent_Cells_Source_Type=Competent_Cells_Source_Type,
        Transformation_Destination_Type=Transformation_Destination_Type,
        Media_Source_Type=Media_Source_Type,
        DNA_Volume_Per_Transformation=DNA_Per_Transformation,
        Competent_Cell_Volume_Per_Transformation=Competent_Cells_Volume,
        Transformation_Final_Volume=Final_Volume,
        Heat_Shock_Time=Heat_Shock_Time,
        Heat_Shock_Temp=Heat_Shock_Temp,
        Media_Aliquot_Volume=Media_Aliquot_Vol,
        Competent_Cells_Aliquot_Volume=Competent_Cells_Aliquot_Vol,
        Wait_Before_Shock=Wait_Before_Shock,
        Replicates=Reps,
#         Shuffle = [".", "shuffle"],
        Cooled_Cells_Modules=Comp_Cells_Modules,
#         Heat_Shock_Modules=["Thermocycler Module", "temperature module gen2"],
        Starting_20uL_Tip = Starting_20uL_Tip,
        Starting_300uL_Tip = Starting_300uL_Tip,
    )
    Transformation.custom_labware_dir = Custom_Labware_Dir
    return(Transformation.run())

# %%
######################################################################
# Use this cell if simulating the protocol, otherwise comment it out #
######################################################################

##########################################################################################################
# IMPORTANT - the protocol will not upload to the opentrons if this cell is not commented out or removed #
##########################################################################################################

from opentrons import simulate as OT2 # This line simulates the protocol
# Get the correct api version
protocol = OT2.get_protocol_api('2.11')
# Home the pipetting head
protocol.home()
# Call the 'run' function to run the protocol
t = run(protocol)
for line in protocol.commands():
    print(line)
# Out:
# C:\Users\bradl\.opentrons\robot_settings.json not found. Loading defaults
# C:\Users\bradl\.opentrons\deck_calibration.json not found. Loading defaults
# Transformation Mapping
# Assembly 1 (B2 of DNA Plate on 5) -> A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Assembly 2 (B3 of DNA Plate on 5) -> B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Assembly 3 (B4 of DNA Plate on 5) -> C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Assembly 4 (B5 of DNA Plate on 5) -> D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Assembly 5 (B6 of DNA Plate on 5) -> E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Assembly 6 (B7 of DNA Plate on 5) -> F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Assembly 7 (B8 of DNA Plate on 5) -> G1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Assembly 8 (B9 of DNA Plate on 5) -> H1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Assembly 9 (B10 of DNA Plate on 5) -> A2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Assembly 10 (B11 of DNA Plate on 5) -> B2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Assembly 11 (B12 of DNA Plate on 5) -> C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Positive (A1 of DNA Tubes on 6) -> D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Negative (A2 of DNA Tubes on 6) -> E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Pausing robot operation: This protocol uses 1 20 uL tip boxes
# Pausing robot operation: This protocol uses 1 300 uL tip boxes
# Pausing robot operation: Place DNA Sample Assembly 1 at B2 of DNA Plate on 5
# Pausing robot operation: Place DNA Sample Assembly 2 at B3 of DNA Plate on 5
# Pausing robot operation: Place DNA Sample Assembly 3 at B4 of DNA Plate on 5
# Pausing robot operation: Place DNA Sample Assembly 4 at B5 of DNA Plate on 5
# Pausing robot operation: Place DNA Sample Assembly 5 at B6 of DNA Plate on 5
# Pausing robot operation: Place DNA Sample Assembly 6 at B7 of DNA Plate on 5
# Pausing robot operation: Place DNA Sample Assembly 7 at B8 of DNA Plate on 5
# Pausing robot operation: Place DNA Sample Assembly 8 at B9 of DNA Plate on 5
# Pausing robot operation: Place DNA Sample Assembly 9 at B10 of DNA Plate on 5
# Pausing robot operation: Place DNA Sample Assembly 10 at B11 of DNA Plate on 5
# Pausing robot operation: Place DNA Sample Assembly 11 at B12 of DNA Plate on 5
# Pausing robot operation: Place DNA Sample Positive at A1 of DNA Tubes on 6
# Pausing robot operation: Place DNA Sample Negative at A2 of DNA Tubes on 6
# Pausing robot operation: This protocol uses 1 aliquots of 5000 uL media, located at [A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7]
# Pausing robot operation: This protocol uses 6 aliquots of 50 uL competent cells, located at [A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3, B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3, C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3, D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3, A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3, B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3]
# Setting Temperature Module temperature to 4.0 °C (rounded off to nearest integer)
# Setting Temperature Module temperature to 4.0 °C (rounded off to nearest integer)
# Picking up tip from A8 of Opentrons 96 Tip Rack 20 µL on 2
# Moving to A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3
# Mixing 5 times with a volume of 20.0 ul
# Aspirating 20.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 7.56 uL/sec
# Moving to A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 20.0 uL into A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Moving to A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Moving to B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3
# Mixing 5 times with a volume of 20.0 ul
# Aspirating 20.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 7.56 uL/sec
# Moving to B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 20.0 uL into B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Moving to B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Moving to C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3
# Mixing 5 times with a volume of 20.0 ul
# Aspirating 20.0 uL from C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 7.56 uL/sec
# Moving to C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 20.0 uL into C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Moving to C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Moving to D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3
# Mixing 5 times with a volume of 20.0 ul
# Aspirating 20.0 uL from D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 7.56 uL/sec
# Moving to D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 20.0 uL into D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Moving to D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Moving to A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3
# Mixing 5 times with a volume of 20.0 ul
# Aspirating 20.0 uL from A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 7.56 uL/sec
# Moving to E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 20.0 uL into E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Moving to E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Moving to B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3
# Mixing 5 times with a volume of 20.0 ul
# Aspirating 20.0 uL from B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 7.56 uL/sec
# Moving to F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 20.0 uL into F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Moving to F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Moving to A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3
# Mixing 5 times with a volume of 20.0 ul
# Aspirating 20.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 7.56 uL/sec
# Moving to G1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 20.0 uL into G1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Moving to G1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at G1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Moving to B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3
# Mixing 5 times with a volume of 20.0 ul
# Aspirating 20.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 7.56 uL/sec
# Moving to H1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 20.0 uL into H1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Moving to H1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at H1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Moving to C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3
# Mixing 5 times with a volume of 20.0 ul
# Aspirating 20.0 uL from C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from C1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 7.56 uL/sec
# Moving to A2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 20.0 uL into A2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Moving to A2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at A2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Moving to D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3
# Mixing 5 times with a volume of 20.0 ul
# Aspirating 20.0 uL from D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from D1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 7.56 uL/sec
# Moving to B2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 20.0 uL into B2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Moving to B2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at B2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Moving to A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3
# Mixing 5 times with a volume of 20.0 ul
# Aspirating 20.0 uL from A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from A2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 7.56 uL/sec
# Moving to C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 20.0 uL into C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Moving to C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Moving to B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3
# Mixing 5 times with a volume of 20.0 ul
# Aspirating 20.0 uL from B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 20.0 uL into B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 20.0 uL from B2 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 7.56 uL/sec
# Moving to D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 20.0 uL into D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Moving to D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Moving to A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3
# Mixing 5 times with a volume of 10.0 ul
# Aspirating 10.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 10.0 uL into A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 10.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 10.0 uL into A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 10.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 10.0 uL into A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 10.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 10.0 uL into A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 10.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 10.0 uL into A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 10.0 uL from A1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 7.56 uL/sec
# Moving to E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 10.0 uL into E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Moving to E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Moving to B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3
# Mixing 5 times with a volume of 10.0 ul
# Aspirating 10.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 10.0 uL into B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 10.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 10.0 uL into B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 10.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 10.0 uL into B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 10.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 10.0 uL into B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 10.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Dispensing 10.0 uL into B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 11.34 uL/sec
# Aspirating 10.0 uL from B1 of 3dprinted 24 Tube Rack 1500 ÂµL on Temperature Module GEN2 on 3 at 7.56 uL/sec
# Moving to E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 10.0 uL into E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Moving to E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from B8 of Opentrons 96 Tip Rack 20 µL on 2
# Moving to B2 of DNA Plate on 5
# Aspirating 3.0 uL from B2 of DNA Plate on 5 at 7.56 uL/sec
# Moving to A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 3.0 uL into A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Mixing 10 times with a volume of 3.0 ul
# Aspirating 3.0 uL from A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Moving to A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from C8 of Opentrons 96 Tip Rack 20 µL on 2
# Moving to B3 of DNA Plate on 5
# Aspirating 3.0 uL from B3 of DNA Plate on 5 at 7.56 uL/sec
# Moving to B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 3.0 uL into B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Mixing 10 times with a volume of 3.0 ul
# Aspirating 3.0 uL from B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Moving to B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from D8 of Opentrons 96 Tip Rack 20 µL on 2
# Moving to B4 of DNA Plate on 5
# Aspirating 3.0 uL from B4 of DNA Plate on 5 at 7.56 uL/sec
# Moving to C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 3.0 uL into C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Mixing 10 times with a volume of 3.0 ul
# Aspirating 3.0 uL from C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Moving to C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from E8 of Opentrons 96 Tip Rack 20 µL on 2
# Moving to B5 of DNA Plate on 5
# Aspirating 3.0 uL from B5 of DNA Plate on 5 at 7.56 uL/sec
# Moving to D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 3.0 uL into D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Mixing 10 times with a volume of 3.0 ul
# Aspirating 3.0 uL from D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Moving to D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from F8 of Opentrons 96 Tip Rack 20 µL on 2
# Moving to B6 of DNA Plate on 5
# Aspirating 3.0 uL from B6 of DNA Plate on 5 at 7.56 uL/sec
# Moving to E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 3.0 uL into E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Mixing 10 times with a volume of 3.0 ul
# Aspirating 3.0 uL from E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Moving to E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from G8 of Opentrons 96 Tip Rack 20 µL on 2
# Moving to B7 of DNA Plate on 5
# Aspirating 3.0 uL from B7 of DNA Plate on 5 at 7.56 uL/sec
# Moving to F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 3.0 uL into F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Mixing 10 times with a volume of 3.0 ul
# Aspirating 3.0 uL from F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Moving to F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# ...
# Dispensing 3.0 uL into C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Moving to C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from E9 of Opentrons 96 Tip Rack 20 µL on 2
# Moving to A1 of DNA Tubes on 6
# Aspirating 3.0 uL from A1 of DNA Tubes on 6 at 7.56 uL/sec
# Moving to D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 3.0 uL into D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Mixing 10 times with a volume of 3.0 ul
# Aspirating 3.0 uL from D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Moving to D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from F9 of Opentrons 96 Tip Rack 20 µL on 2
# Moving to A2 of DNA Tubes on 6
# Aspirating 3.0 uL from A2 of DNA Tubes on 6 at 7.56 uL/sec
# Moving to E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 3.0 uL into E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 7.56 uL/sec
# Mixing 10 times with a volume of 3.0 ul
# Aspirating 3.0 uL from E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Aspirating 3.0 uL from E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Dispensing 3.0 uL into E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 15.12 uL/sec
# Moving to E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Blowing out at E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Delaying for 5 minutes and 0.0 seconds
# Setting Temperature Module temperature to 42.0 °C (rounded off to nearest integer)
# Delaying for 0 minutes and 30.0 seconds
# Setting Temperature Module temperature to 4.0 °C (rounded off to nearest integer)
# Delaying for 2 minutes and 0.0 seconds
# Pausing robot operation: Open up LB tubes
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 4
# Moving to A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7
# Aspirating 77.0 uL from A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7 at 92.86 uL/sec
# Moving to A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 77.0 uL into A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 92.86 uL/sec
# Blowing out at A1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from B1 of Opentrons 96 Tip Rack 300 µL on 4
# Moving to A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7
# Aspirating 77.0 uL from A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7 at 92.86 uL/sec
# Moving to B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 77.0 uL into B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 92.86 uL/sec
# Blowing out at B1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from C1 of Opentrons 96 Tip Rack 300 µL on 4
# Moving to A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7
# Aspirating 77.0 uL from A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7 at 92.86 uL/sec
# Moving to C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 77.0 uL into C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 92.86 uL/sec
# Blowing out at C1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from D1 of Opentrons 96 Tip Rack 300 µL on 4
# Moving to A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7
# Aspirating 77.0 uL from A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7 at 92.86 uL/sec
# Moving to D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 77.0 uL into D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 92.86 uL/sec
# Blowing out at D1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from E1 of Opentrons 96 Tip Rack 300 µL on 4
# Moving to A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7
# Aspirating 77.0 uL from A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7 at 92.86 uL/sec
# Moving to E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 77.0 uL into E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 92.86 uL/sec
# Blowing out at E1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from F1 of Opentrons 96 Tip Rack 300 µL on 4
# Moving to A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7
# Aspirating 77.0 uL from A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7 at 92.86 uL/sec
# Moving to F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 77.0 uL into F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 92.86 uL/sec
# Blowing out at F1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from G1 of Opentrons 96 Tip Rack 300 µL on 4
# Moving to A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7
# Aspirating 77.0 uL from A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7 at 92.86 uL/sec
# Moving to G1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 77.0 uL into G1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 92.86 uL/sec
# Blowing out at G1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from H1 of Opentrons 96 Tip Rack 300 µL on 4
# Moving to A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7
# Aspirating 77.0 uL from A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7 at 92.86 uL/sec
# Moving to H1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 77.0 uL into H1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 92.86 uL/sec
# Blowing out at H1 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 4
# Moving to A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7
# Aspirating 77.0 uL from A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7 at 92.86 uL/sec
# Moving to A2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 77.0 uL into A2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 92.86 uL/sec
# Blowing out at A2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from B2 of Opentrons 96 Tip Rack 300 µL on 4
# Moving to A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7
# Aspirating 77.0 uL from A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7 at 92.86 uL/sec
# Moving to B2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 77.0 uL into B2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 92.86 uL/sec
# Blowing out at B2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from C2 of Opentrons 96 Tip Rack 300 µL on 4
# Moving to A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7
# Aspirating 77.0 uL from A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7 at 92.86 uL/sec
# Moving to C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 77.0 uL into C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 92.86 uL/sec
# Blowing out at C2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from D2 of Opentrons 96 Tip Rack 300 µL on 4
# Moving to A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7
# Aspirating 77.0 uL from A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7 at 92.86 uL/sec
# Moving to D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 77.0 uL into D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 92.86 uL/sec
# Blowing out at D2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from E2 of Opentrons 96 Tip Rack 300 µL on 4
# Moving to A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7
# Aspirating 77.0 uL from A1 of 3dprinted 15 Tube Rack 15000 ÂµL on 7 at 92.86 uL/sec
# Moving to E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Dispensing 77.0 uL into E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1 at 92.86 uL/sec
# Blowing out at E2 of Nunclon Delta Surface 163320 96 Well Plate 250 ÂµL on Temperature Module GEN2 on 1
# Touching tip
# Dropping tip into A1 of Opentrons Fixed Trash on 12

# %%
str(protocol.deck[3])
# Out:
# 'Temperature Module GEN2 on 3'

# %%
location.well_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_75796/3589625758.py in <module>
# ----> 1 location.well_name
#
# NameError: name 'location' is not defined

# %%
for i in protocol.deck:
    print(protocol.deck[i])

# %%
protocol.commands().count("Setting Temperature Module temperature to 4.0 °C (rounded off to nearest integer)")

# %%
len(protocol.commands())

# %%
a = ["h", "sadf", "h", "gfdgdskf"]

# %%
a.count("h")

# %%
"Opening Thermocycler lid" in protocol.commands()

# %%
protocol._modules[0]._module.model()
